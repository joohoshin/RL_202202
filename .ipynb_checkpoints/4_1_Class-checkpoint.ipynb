# %% [markdown]
# 파이썬 클래스를 알아보자
#
# 함수와 데이터를 함께 저장하기 위해서 클래스를 사용한다.
#
# https://wikidocs.net/28

# %%
class neural():
  def __init__(self):
    self.w = 0
  def forward(self,n):
    self.w+= n
  def show(self):
    print(self.w)

# %%
n = neural()  # Instance 만들기

# %%
n.forward(1)

# %%
n.forward(2)

# %%
n.show()
# Out:
# 3

# %% [markdown]
# 클래스 상속을 알아보자
#
# 상속을 통해 부모 클래스의 함수들을 사용할 수 있다.
#
# 또한 일부 함수는 재정의해서 사용할 수 있다.

# %%
class mynn(neural):
  def __init__(self):
    super().__init__()    
  def forward(self, n):
    self.w -= n

# %%
m = mynn()

# %%
m.forward(3)

# %%
m.show()
# Out:
# -3
